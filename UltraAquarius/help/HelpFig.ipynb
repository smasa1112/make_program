# %%
import numpy
import matplotlib.pyplot as plt

# %%
def taper(data,percent):
    tmp = data
    for i,j in enumerate(tmp): 
        if len(data)*percent > i:
            tmp[i] *= i/(percent*len(data))
        elif len(data)*(1-percent) < i:
            tmp[i] *= ((len(data)-i)/(percent*len(data)))
        else:
            tmp[i]  = tmp[i]
    return tmp
def sintaper(data,percent):
    tmp = data
    for i,j in enumerate(tmp): 
        if len(data)*percent > i:
            tmp[i] *= numpy.sin(i/(percent*len(data))*0.5*numpy.pi)
        elif len(data)*(1-percent) < i:
            tmp[i] *= numpy.sin(((len(data)-i)/(percent*len(data)))*0.5*numpy.pi)
        else:
            tmp[i]  = tmp[i]
    return tmp
def pulse(data,pre,duration,post):
    tmp = data
    for i,j in enumerate(tmp): 
        if len(data)*pre > i:
            tmp[i] *= 0
        elif len(data)*(1-post) < i:
            tmp[i] *= 0
        else:
            tmp[i]  = 1
    return tmp

# %%
waves = 50
t = numpy.linspace(0,waves*numpy.pi,10**5)
d_len = len(t)
plt.figure(figsize = (8,12))

plt.subplot(3,1,1)
plt.plot(numpy.sin(t))
plt.title("PureTone")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)

plt.subplot(3,1,2)
plt.plot(taper(numpy.sin(t),0.5))
plt.title("TonePip")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)

plt.subplot(3,1,3)
plt.plot(taper(numpy.sin(t),0.1))
plt.title("ToneBurst")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)
plt.savefig("PureTone.png",dpi = 80, bbox_inches='tight', pad_inches=0)

# %%
plt.figure(figsize = (8,4))
waves = 50
t = numpy.linspace(0,waves*numpy.pi,10**5)
d_len = len(t)
plt.plot(pulse(t,0.001,0.2,0.8-0.001))
plt.title("Click")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.savefig("Click.png",dpi = 80, bbox_inches='tight', pad_inches=0)

# %%
plt.figure(figsize = (8,4))
waves = 50
t = numpy.linspace(0,waves*numpy.pi,10**5)
d_len = len(t)
plt.plot(numpy.sin(t)*numpy.sin(t/10))
plt.title("AMTone")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.savefig("AMTone.png",dpi = 80, bbox_inches='tight', pad_inches=0)

# %%
plt.figure(figsize = (8,4))
waves = 20
t = numpy.linspace(0,waves*numpy.pi,10**3)
d_len = len(t)
tmp = numpy.sin(t)*pulse(numpy.sin(t),0.001,0.3,0.7-0.001)
plt.plot(numpy.hstack((tmp,tmp,tmp,tmp)))
plt.title("Ultrasound")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len*4 *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.savefig("Ultrasound.png",dpi = 80, bbox_inches='tight', pad_inches=0)

# %%
waves = 50
t = numpy.linspace(0,waves*numpy.pi,10**5)
d_len = len(t)
plt.figure(figsize = (8,8))

plt.subplot(2,1,1)
plt.plot(taper(numpy.sin(t),0.3))
plt.title("LinerWindow")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)

plt.subplot(2,1,2)
plt.plot(sintaper(numpy.sin(t),0.3))
plt.title("SineWindow")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)

plt.savefig("USMod.png",dpi = 80, bbox_inches='tight', pad_inches=0)

# %%
waves = 50
t = numpy.linspace(0,waves*numpy.pi,10**5)
d_len = len(t)
plt.figure(figsize = (8,12))

plt.subplot(3,1,1)
plt.plot(numpy.sin(t))
plt.title("Sine")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)

plt.subplot(3,1,2)
plt.plot(numpy.hstack((1/(1 +numpy.exp(-1*numpy.linspace(-6,6,10**5//8))),numpy.ones(10**5//4),1/(1 +numpy.exp(numpy.linspace(-6,6,10**5//8))),numpy.zeros(10**5//2))))
plt.title("Pulse")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)

plt.subplot(3,1,3)
plt.plot(pulse(numpy.sin(t),0.001,0.5,0.5-0.001))
plt.title("Square")
plt.tick_params(labelbottom=True, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(bottom=True, left=False, right=False, top=False)
plt.xticks([d_len *round(x,1) for x in list(numpy.linspace(0,1,11))],[str(round(x,1)) for x in list(numpy.linspace(0,1,11))])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
#plt.gca().spines['bottom'].set_visible(False)
plt.savefig("Magnetic.png",dpi = 80, bbox_inches='tight', pad_inches=0)
